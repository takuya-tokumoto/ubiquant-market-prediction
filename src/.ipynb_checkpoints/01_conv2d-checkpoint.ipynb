# %% [markdown]
# - https://www.kaggle.com/code/pythonash/end-to-end-simple-and-powerful-dnn-with-leakyrelu

# %% [markdown]
# # If you copy this notebook, please upvote !!
#
# ##  Market Prediction with Conv2d
# It is assumed that there is a complex relationship between the features.
#
# The relationship is clarified by spatial analysis.
#
# LB = 0.152
#
# Derived from Conv1d ver. The difference in performance from previous version is under verification.
# ### Refrence
# Special thanks @Lonnie Ubiquant Market Prediction with DNN
#
# - https://www.kaggle.com/lonnieqin/ubiquant-market-prediction-with-dnn##
#
# Conv1d version is here
# - https://www.kaggle.com/code/shigeeeru/prediction-including-spatial-info-with-conv1d
#
# ### Note
# - delete investment feature
# - add random.set_seed

# %%
import os
import pandas as pd
import numpy as np
import gc
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import keras
from scipy import stats
from tensorflow.python.ops import math_ops
from tensorflow.python.keras import backend as K

### add random seed
tf.random.set_seed(3)

# %% [markdown]
# ## Configuration
#
# If you want to train model, change 'is_trainig' to 'True'.

# %%
class Config:
#     is_training = False
    is_training = True
    tf_record_dataset_path = "../input/ump-combinatorialpurgedgroupkfold-tf-record/"
    ### change here ###
    output_dataset_path = "../input/ump-conv2d-fold5-outputs/"
config = Config()

# %% [markdown]
# ## Create an IntegerLookup layer for investment_id input

# %%
# %%time
investment_ids = pd.read_csv("../input/ump-combinatorialpurgedgroupkfold-tf-record/investment_ids.csv")
investment_id_size = len(investment_ids) + 1
with tf.device("cpu"):
    investment_id_lookup_layer = layers.IntegerLookup(max_tokens=investment_id_size)
    investment_id_lookup_layer.adapt(investment_ids)
# Out:
# 2022-04-11 11:47:57.592907: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 11:47:57.724439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 11:47:57.725221: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 11:47:57.727229: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-11 11:47:57.728267: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 11:47:57.728953: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 11:47:57.729603: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 11:47:59.543980: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 11:47:59.544869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 11:47:59.545575: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 11:47:59.546229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# 2022-04-11 11:47:59.669021: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# CPU times: user 649 ms, sys: 350 ms, total: 999 ms
# Wall time: 2.38 s

# %% [markdown]
# ## Make Tensorflow dataset

# %%
def decode_function(record_bytes):
    return tf.io.parse_single_example(
      # Data
      record_bytes,
      # Schema
      {
          "features": tf.io.FixedLenFeature([300], dtype=tf.float32),
          "time_id": tf.io.FixedLenFeature([], dtype=tf.int64),
          "investment_id": tf.io.FixedLenFeature([], dtype=tf.int64),
          "target": tf.io.FixedLenFeature([], dtype=tf.float32)
      }
  )
# def preprocess(item):
#     return (item["investment_id"], item["features"]), item["target"]
def preprocess(item):
    return (item["features"]), item["target"]
def make_dataset(file_paths, batch_size=4096, mode="train"):
    ds = tf.data.TFRecordDataset(file_paths)
    ds = ds.map(decode_function)
    ds = ds.map(preprocess)
    if mode == "train":
        ds = ds.shuffle(batch_size * 4)
    ds = ds.batch(batch_size).cache().prefetch(tf.data.AUTOTUNE)
    return ds

# %% [markdown]
# ## Modeling
#
# I use layers.Conv1d.
#
# [source is here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv1D)

# %%
def correlation(x, y, axis=-2):
    """Metric returning the Pearson correlation coefficient of two tensors over some axis, default -2."""
    x = tf.convert_to_tensor(x)
    y = math_ops.cast(y, x.dtype)
    n = tf.cast(tf.shape(x)[axis], x.dtype)
    xsum = tf.reduce_sum(x, axis=axis)
    ysum = tf.reduce_sum(y, axis=axis)
    xmean = xsum / n
    ymean = ysum / n
    ###    不偏分散にしたら？？   ###
    
    xvar = tf.reduce_sum( tf.math.squared_difference(x, xmean), axis=axis)
    yvar = tf.reduce_sum( tf.math.squared_difference(y, ymean), axis=axis)

    cov = tf.reduce_sum( (x - xmean) * (y - ymean), axis=axis)
    corr = cov / tf.sqrt(xvar * yvar)
    return tf.constant(1.0, dtype=x.dtype) - corr

def get_model():
    features_inputs = tf.keras.Input((300, ), dtype=tf.float16)
    
    ## Dense 1 ##
    feature_x = layers.Dense(256, activation='swish', kernel_initializer = 'he_normal')(features_inputs)
    feature_x = layers.Dropout(0.1)(feature_x)
#     ## Dense 2 ##
#     feature_x = layers.Dense(256, activation='swish')(feature_x)
#     feature_x = layers.Dropout(0.1)(feature_x)
    ## convolution 1 ##
    feature_x = layers.Reshape((-1,1))(feature_x)
    feature_x = layers.Conv1D(filters=16, kernel_size=4, strides=1, padding='same', kernel_initializer = 'he_normal')(feature_x)
    feature_x = layers.BatchNormalization()(feature_x)
    feature_x = layers.LeakyReLU(0.5)(feature_x)
    ## convolution 2 ##
    feature_x = layers.Conv1D(filters=16, kernel_size=4, strides=4, padding='same', kernel_initializer = 'he_normal')(feature_x)
    feature_x = layers.BatchNormalization()(feature_x)
    feature_x = layers.LeakyReLU(0.5)(feature_x)
    ## convolution 3 ##
    feature_x = layers.Conv1D(filters=64, kernel_size=4, strides=1, padding='same', kernel_initializer = 'he_normal')(feature_x)
    feature_x = layers.BatchNormalization()(feature_x)
    feature_x = layers.LeakyReLU(0.5)(feature_x)

    ## convolution2D 1 ##
    feature_x = layers.Reshape((64,64,1))(feature_x)
    feature_x = layers.Conv2D(filters=32, kernel_size=4, strides=1, padding='same', kernel_initializer = 'he_normal')(feature_x)
    feature_x = layers.BatchNormalization()(feature_x)
    feature_x = layers.LeakyReLU(0.5)(feature_x)
    ## convolution2D 2 ##
    feature_x = layers.Conv2D(filters=32, kernel_size=4, strides=4, padding='same', kernel_initializer = 'he_normal')(feature_x)
    feature_x = layers.BatchNormalization()(feature_x)
    feature_x = layers.LeakyReLU(0.5)(feature_x)
    ## convolution2D 3 ##
    feature_x = layers.Conv2D(filters=32, kernel_size=4, strides=4, padding='same', kernel_initializer = 'he_normal')(feature_x)
    feature_x = layers.BatchNormalization()(feature_x)
    feature_x = layers.LeakyReLU(0.5)(feature_x)

    ## flatten ##
    feature_x = layers.Flatten()(feature_x)
    ## Dense 3 ##
    x = layers.Dense(512, activation='swish', kernel_regularizer="l2", kernel_initializer = 'he_normal')(feature_x)
    ## Dense 4 ##
    x = layers.Dropout(0.1)(x)
    ## Dense 5 ##    
    x = layers.Dense(128, activation='swish', kernel_regularizer="l2", kernel_initializer = 'he_normal')(x)
    x = layers.Dropout(0.1)(x)
    ## Dense 6 ##
    x = layers.Dense(32, activation='swish', kernel_regularizer="l2", kernel_initializer = 'he_normal')(x)
    x = layers.Dropout(0.1)(x)
    ## Dense 7 ##
    output = layers.Dense(1)(x)
    rmse = keras.metrics.RootMeanSquaredError(name="rmse")
    model = tf.keras.Model(inputs=[features_inputs], outputs=[output])
    
    
    learning_sch = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate = 0.001,
        decay_steps = 9700,
        decay_rate = 0.98
    )
    adam = tf.keras.optimizers.Adam(learning_rate = learning_sch)
    
    
    model.compile(optimizer = adam, loss='mse', metrics=['mse', "mae", "mape", rmse, correlation])
    return model

# %% [markdown]
# Let's take a look at this Model's architecture.

# %%
model = get_model()
model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               77056
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# reshape (Reshape)            (None, 256, 1)            0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 256, 16)           80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256, 16)           64
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 256, 16)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 64, 16)            1040
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 16)            64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 64, 64)            4160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64)            256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64, 64)            0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 32)        544
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 32)        16416
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 32)          16416
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4, 4, 32)          128
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 448,961
# Trainable params: 448,577
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ## Model Training

# %%
# %%time
models = []
for i in range(5):
    train_path = f"{config.tf_record_dataset_path}fold_{i}_train.tfrecords"
    valid_path = f"{config.tf_record_dataset_path}fold_{i}_test.tfrecords"
    valid_ds = make_dataset([valid_path], mode="valid")
    print(valid_ds)
    model = get_model()
    if config.is_training:
        train_ds = make_dataset([train_path])
        checkpoint = keras.callbacks.ModelCheckpoint(f"model_{i}.tf", monitor="val_correlation", mode="min", save_best_only=True, save_weights_only=True)
        early_stop = keras.callbacks.EarlyStopping(patience=10)
        history = model.fit(train_ds, epochs=50, validation_data=valid_ds, callbacks=[checkpoint, early_stop])
        model.save_weights(f"model_{i}.tf")
        for metric in ["loss", "mae", "mape", "rmse", "correlation"]:
            pd.DataFrame(history.history, columns=[metric, f"val_{metric}"]).plot()
            plt.title(metric.upper())
            plt.show()
    else:
        model.load_weights(f"{config.output_dataset_path}model_{i}.tf")
    y_vals = []
    for _, y in valid_ds:
        y_vals += list(y.numpy().reshape(-1))
    y_val = np.array(y_vals)
    pearson_score = stats.pearsonr(model.predict(valid_ds).reshape(-1), y_val)[0]
    models.append(model)
    print(f"Pearson Score: {pearson_score}")
# Out:
# <PrefetchDataset shapes: ((None, 300), (None,)), types: (tf.float32, tf.float32)>
# Epoch 1/50
# 2022-04-11 11:48:07.373594: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 627/627 [==============================] - 254s 389ms/step - loss: 2.2537 - mse: 0.8361 - mae: 0.6252 - mape: 161587.0938 - rmse: 0.9144 - correlation: 0.8876 - val_loss: 0.8894 - val_mse: 0.8641 - val_mae: 0.6455 - val_mape: 63120.0273 - val_rmse: 0.9296 - val_correlation: 0.9220
# Epoch 2/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8382 - mse: 0.8263 - mae: 0.6216 - mape: 139036.3750 - rmse: 0.9090 - correlation: 0.8666 - val_loss: 0.8673 - val_mse: 0.8631 - val_mae: 0.6448 - val_mape: 72235.3750 - val_rmse: 0.9290 - val_correlation: 0.9170
# Epoch 3/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8294 - mse: 0.8239 - mae: 0.6206 - mape: 146395.4531 - rmse: 0.9077 - correlation: 0.8569 - val_loss: 0.8655 - val_mse: 0.8630 - val_mae: 0.6455 - val_mape: 64880.5625 - val_rmse: 0.9290 - val_correlation: 0.9126
# Epoch 4/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8269 - mse: 0.8220 - mae: 0.6199 - mape: 146580.8125 - rmse: 0.9066 - correlation: 0.8498 - val_loss: 0.8649 - val_mse: 0.8623 - val_mae: 0.6445 - val_mape: 93689.3750 - val_rmse: 0.9286 - val_correlation: 0.9121
# Epoch 5/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8256 - mse: 0.8204 - mae: 0.6194 - mape: 153427.9844 - rmse: 0.9058 - correlation: 0.8440 - val_loss: 0.8659 - val_mse: 0.8626 - val_mae: 0.6437 - val_mape: 128741.0234 - val_rmse: 0.9287 - val_correlation: 0.9111
# Epoch 6/50
# 627/627 [==============================] - 168s 269ms/step - loss: 0.8245 - mse: 0.8184 - mae: 0.6186 - mape: 161827.7344 - rmse: 0.9047 - correlation: 0.8364 - val_loss: 0.8649 - val_mse: 0.8617 - val_mae: 0.6434 - val_mape: 119818.7422 - val_rmse: 0.9283 - val_correlation: 0.9086
# Epoch 7/50
# 627/627 [==============================] - 168s 269ms/step - loss: 0.8233 - mse: 0.8164 - mae: 0.6178 - mape: 165903.3438 - rmse: 0.9036 - correlation: 0.8302 - val_loss: 0.8648 - val_mse: 0.8616 - val_mae: 0.6436 - val_mape: 111975.7891 - val_rmse: 0.9282 - val_correlation: 0.9083
# Epoch 8/50
# 627/627 [==============================] - 168s 269ms/step - loss: 0.8214 - mse: 0.8139 - mae: 0.6167 - mape: 173762.6719 - rmse: 0.9022 - correlation: 0.8219 - val_loss: 0.8650 - val_mse: 0.8617 - val_mae: 0.6443 - val_mape: 92165.0234 - val_rmse: 0.9283 - val_correlation: 0.9077
# Epoch 9/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8202 - mse: 0.8120 - mae: 0.6161 - mape: 162333.2812 - rmse: 0.9011 - correlation: 0.8161 - val_loss: 0.8649 - val_mse: 0.8609 - val_mae: 0.6440 - val_mape: 91541.2031 - val_rmse: 0.9278 - val_correlation: 0.9028
# Epoch 10/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8179 - mse: 0.8092 - mae: 0.6151 - mape: 170564.2969 - rmse: 0.8996 - correlation: 0.8082 - val_loss: 0.8648 - val_mse: 0.8605 - val_mae: 0.6445 - val_mape: 92570.2266 - val_rmse: 0.9276 - val_correlation: 0.8994
# Epoch 11/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8158 - mse: 0.8065 - mae: 0.6142 - mape: 172604.4219 - rmse: 0.8981 - correlation: 0.8005 - val_loss: 0.8667 - val_mse: 0.8616 - val_mae: 0.6451 - val_mape: 88968.0234 - val_rmse: 0.9282 - val_correlation: 0.9042
# Epoch 12/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8136 - mse: 0.8038 - mae: 0.6132 - mape: 172822.0625 - rmse: 0.8966 - correlation: 0.7929 - val_loss: 0.8664 - val_mse: 0.8611 - val_mae: 0.6454 - val_mape: 89059.6953 - val_rmse: 0.9280 - val_correlation: 0.9006
# Epoch 13/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8115 - mse: 0.8014 - mae: 0.6125 - mape: 182914.7500 - rmse: 0.8952 - correlation: 0.7866 - val_loss: 0.8681 - val_mse: 0.8620 - val_mae: 0.6468 - val_mape: 87545.2188 - val_rmse: 0.9284 - val_correlation: 0.9025
# Epoch 14/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8098 - mse: 0.7990 - mae: 0.6118 - mape: 186573.6406 - rmse: 0.8939 - correlation: 0.7806 - val_loss: 0.8698 - val_mse: 0.8635 - val_mae: 0.6471 - val_mape: 97743.4609 - val_rmse: 0.9292 - val_correlation: 0.9082
# Epoch 15/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8079 - mse: 0.7970 - mae: 0.6113 - mape: 192720.0938 - rmse: 0.8927 - correlation: 0.7754 - val_loss: 0.8710 - val_mse: 0.8640 - val_mae: 0.6463 - val_mape: 113084.2578 - val_rmse: 0.9295 - val_correlation: 0.9100
# Epoch 16/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8064 - mse: 0.7950 - mae: 0.6107 - mape: 198991.5781 - rmse: 0.8916 - correlation: 0.7699 - val_loss: 0.8716 - val_mse: 0.8642 - val_mae: 0.6467 - val_mape: 106888.5391 - val_rmse: 0.9296 - val_correlation: 0.9116
# Epoch 17/50
# 627/627 [==============================] - 168s 268ms/step - loss: 0.8043 - mse: 0.7927 - mae: 0.6102 - mape: 207564.5469 - rmse: 0.8903 - correlation: 0.7644 - val_loss: 0.8741 - val_mse: 0.8664 - val_mae: 0.6487 - val_mape: 108552.5781 - val_rmse: 0.9308 - val_correlation: 0.9204
# Pearson Score: 0.07977130246010611
# <PrefetchDataset shapes: ((None, 300), (None,)), types: (tf.float32, tf.float32)>
# Epoch 1/50
# 637/637 [==============================] - 244s 376ms/step - loss: 2.0503 - mse: 0.8473 - mae: 0.6223 - mape: 135720.4531 - rmse: 0.9205 - correlation: 0.8930 - val_loss: 0.8170 - val_mse: 0.8076 - val_mae: 0.6665 - val_mape: 42085.1055 - val_rmse: 0.8987 - val_correlation: 0.8872
# Epoch 2/50
# 637/637 [==============================] - 170s 267ms/step - loss: 0.8457 - mse: 0.8399 - mae: 0.6195 - mape: 134433.9688 - rmse: 0.9165 - correlation: 0.8750 - val_loss: 0.8081 - val_mse: 0.8054 - val_mae: 0.6652 - val_mape: 51506.6602 - val_rmse: 0.8975 - val_correlation: 0.8819
# Epoch 3/50
# 637/637 [==============================] - 170s 267ms/step - loss: 0.8418 - mse: 0.8374 - mae: 0.6186 - mape: 143758.8906 - rmse: 0.9151 - correlation: 0.8644 - val_loss: 0.8049 - val_mse: 0.8017 - val_mae: 0.6616 - val_mape: 103110.4922 - val_rmse: 0.8954 - val_correlation: 0.8821
# Epoch 4/50
# 637/637 [==============================] - 170s 267ms/step - loss: 0.8403 - mse: 0.8354 - mae: 0.6177 - mape: 144198.1562 - rmse: 0.9140 - correlation: 0.8558 - val_loss: 0.8041 - val_mse: 0.8008 - val_mae: 0.6601 - val_mape: 119445.3672 - val_rmse: 0.8949 - val_correlation: 0.8792
# Epoch 5/50
# 637/637 [==============================] - 170s 268ms/step - loss: 0.8391 - mse: 0.8336 - mae: 0.6171 - mape: 149772.4375 - rmse: 0.9130 - correlation: 0.8485 - val_loss: 0.8045 - val_mse: 0.8012 - val_mae: 0.6600 - val_mape: 119724.0781 - val_rmse: 0.8951 - val_correlation: 0.8810
# Epoch 6/50
# 637/637 [==============================] - 171s 268ms/step - loss: 0.8378 - mse: 0.8315 - mae: 0.6162 - mape: 151152.1875 - rmse: 0.9119 - correlation: 0.8411 - val_loss: 0.8061 - val_mse: 0.8019 - val_mae: 0.6607 - val_mape: 108829.6250 - val_rmse: 0.8955 - val_correlation: 0.8832
# Epoch 7/50
# 637/637 [==============================] - 171s 268ms/step - loss: 0.8368 - mse: 0.8300 - mae: 0.6156 - mape: 150397.5000 - rmse: 0.9110 - correlation: 0.8359 - val_loss: 0.8073 - val_mse: 0.8025 - val_mae: 0.6610 - val_mape: 118022.6641 - val_rmse: 0.8958 - val_correlation: 0.8836
# Epoch 8/50
# 637/637 [==============================] - 171s 268ms/step - loss: 0.8355 - mse: 0.8281 - mae: 0.6150 - mape: 148381.5469 - rmse: 0.9100 - correlation: 0.8292 - val_loss: 0.8054 - val_mse: 0.8011 - val_mae: 0.6607 - val_mape: 95911.9297 - val_rmse: 0.8950 - val_correlation: 0.8791
# Epoch 9/50
# 637/637 [==============================] - 171s 268ms/step - loss: 0.8341 - mse: 0.8260 - mae: 0.6142 - mape: 156701.9219 - rmse: 0.9088 - correlation: 0.8227 - val_loss: 0.8051 - val_mse: 0.8004 - val_mae: 0.6598 - val_mape: 90306.6016 - val_rmse: 0.8947 - val_correlation: 0.8761
# Epoch 10/50
# 637/637 [==============================] - 170s 268ms/step - loss: 0.8330 - mse: 0.8243 - mae: 0.6137 - mape: 160964.0938 - rmse: 0.9079 - correlation: 0.8174 - val_loss: 0.8056 - val_mse: 0.8008 - val_mae: 0.6607 - val_mape: 69460.6484 - val_rmse: 0.8949 - val_correlation: 0.8736
# Epoch 11/50
# 637/637 [==============================] - 171s 268ms/step - loss: 0.8312 - mse: 0.8223 - mae: 0.6131 - mape: 165225.4531 - rmse: 0.9068 - correlation: 0.8115 - val_loss: 0.8054 - val_mse: 0.8003 - val_mae: 0.6605 - val_mape: 83139.3203 - val_rmse: 0.8946 - val_correlation: 0.8719
# Epoch 12/50
# 637/637 [==============================] - 171s 268ms/step - loss: 0.8294 - mse: 0.8200 - mae: 0.6123 - mape: 170937.4375 - rmse: 0.9055 - correlation: 0.8051 - val_loss: 0.8060 - val_mse: 0.8008 - val_mae: 0.6611 - val_mape: 77906.6641 - val_rmse: 0.8949 - val_correlation: 0.8700
# Epoch 13/50
# 637/637 [==============================] - 171s 268ms/step - loss: 0.8283 - mse: 0.8184 - mae: 0.6118 - mape: 172560.9531 - rmse: 0.9047 - correlation: 0.8005 - val_loss: 0.8053 - val_mse: 0.8002 - val_mae: 0.6609 - val_mape: 93207.2188 - val_rmse: 0.8946 - val_correlation: 0.8696
# Epoch 14/50
# 637/637 [==============================] - 171s 268ms/step - loss: 0.8264 - mse: 0.8165 - mae: 0.6113 - mape: 180297.6406 - rmse: 0.9036 - correlation: 0.7953 - val_loss: 0.8061 - val_mse: 0.8007 - val_mae: 0.6615 - val_mape: 85878.9531 - val_rmse: 0.8948 - val_correlation: 0.8709
# Pearson Score: 0.12641284877449038
# <PrefetchDataset shapes: ((None, 300), (None,)), types: (tf.float32, tf.float32)>
# Epoch 1/50
# 611/611 [==============================] - 256s 413ms/step - loss: 2.4519 - mse: 0.8419 - mae: 0.6301 - mape: 145518.5938 - rmse: 0.9175 - correlation: 0.8919 - val_loss: 0.8848 - val_mse: 0.8475 - val_mae: 0.6299 - val_mape: 88924.7891 - val_rmse: 0.9206 - val_correlation: 0.8967
# Epoch 2/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8461 - mse: 0.8307 - mae: 0.6259 - mape: 124013.7266 - rmse: 0.9114 - correlation: 0.8724 - val_loss: 0.8515 - val_mse: 0.8468 - val_mae: 0.6298 - val_mape: 100475.5625 - val_rmse: 0.9202 - val_correlation: 0.8938
# Epoch 3/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8339 - mse: 0.8282 - mae: 0.6249 - mape: 129859.4922 - rmse: 0.9101 - correlation: 0.8620 - val_loss: 0.8486 - val_mse: 0.8453 - val_mae: 0.6285 - val_mape: 144263.9062 - val_rmse: 0.9194 - val_correlation: 0.8944
# Epoch 4/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8316 - mse: 0.8261 - mae: 0.6241 - mape: 128469.2500 - rmse: 0.9089 - correlation: 0.8533 - val_loss: 0.8481 - val_mse: 0.8450 - val_mae: 0.6280 - val_mape: 159821.1094 - val_rmse: 0.9192 - val_correlation: 0.8935
# Epoch 5/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8303 - mse: 0.8246 - mae: 0.6235 - mape: 128696.0469 - rmse: 0.9081 - correlation: 0.8470 - val_loss: 0.8497 - val_mse: 0.8461 - val_mae: 0.6270 - val_mape: 211523.5938 - val_rmse: 0.9198 - val_correlation: 0.8946
# Epoch 6/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8291 - mse: 0.8227 - mae: 0.6228 - mape: 133806.7031 - rmse: 0.9070 - correlation: 0.8396 - val_loss: 0.8493 - val_mse: 0.8455 - val_mae: 0.6273 - val_mape: 167378.5625 - val_rmse: 0.9195 - val_correlation: 0.8956
# Epoch 7/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8278 - mse: 0.8208 - mae: 0.6220 - mape: 132171.7969 - rmse: 0.9060 - correlation: 0.8328 - val_loss: 0.8494 - val_mse: 0.8455 - val_mae: 0.6268 - val_mape: 163455.1406 - val_rmse: 0.9195 - val_correlation: 0.8948
# Epoch 8/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8261 - mse: 0.8185 - mae: 0.6212 - mape: 138500.4219 - rmse: 0.9047 - correlation: 0.8256 - val_loss: 0.8490 - val_mse: 0.8447 - val_mae: 0.6266 - val_mape: 126983.3281 - val_rmse: 0.9191 - val_correlation: 0.8918
# Epoch 9/50
# 611/611 [==============================] - 166s 271ms/step - loss: 0.8244 - mse: 0.8162 - mae: 0.6203 - mape: 143378.9219 - rmse: 0.9034 - correlation: 0.8183 - val_loss: 0.8487 - val_mse: 0.8437 - val_mae: 0.6260 - val_mape: 126135.8281 - val_rmse: 0.9185 - val_correlation: 0.8866
# Epoch 10/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8228 - mse: 0.8137 - mae: 0.6194 - mape: 150090.4062 - rmse: 0.9020 - correlation: 0.8101 - val_loss: 0.8486 - val_mse: 0.8435 - val_mae: 0.6262 - val_mape: 140288.5312 - val_rmse: 0.9184 - val_correlation: 0.8856
# Epoch 11/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8213 - mse: 0.8113 - mae: 0.6186 - mape: 153183.7812 - rmse: 0.9007 - correlation: 0.8034 - val_loss: 0.8489 - val_mse: 0.8436 - val_mae: 0.6264 - val_mape: 149160.0469 - val_rmse: 0.9185 - val_correlation: 0.8859
# Epoch 12/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8197 - mse: 0.8093 - mae: 0.6179 - mape: 159340.1094 - rmse: 0.8996 - correlation: 0.7975 - val_loss: 0.8500 - val_mse: 0.8441 - val_mae: 0.6265 - val_mape: 158619.5156 - val_rmse: 0.9187 - val_correlation: 0.8882
# Epoch 13/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8180 - mse: 0.8072 - mae: 0.6173 - mape: 166373.1875 - rmse: 0.8984 - correlation: 0.7917 - val_loss: 0.8491 - val_mse: 0.8436 - val_mae: 0.6265 - val_mape: 156107.0469 - val_rmse: 0.9185 - val_correlation: 0.8852
# Epoch 14/50
# 611/611 [==============================] - 165s 270ms/step - loss: 0.8160 - mse: 0.8047 - mae: 0.6165 - mape: 172564.5625 - rmse: 0.8971 - correlation: 0.7855 - val_loss: 0.8504 - val_mse: 0.8443 - val_mae: 0.6268 - val_mape: 150762.7969 - val_rmse: 0.9189 - val_correlation: 0.8871
# Pearson Score: 0.11278186562329794
# <PrefetchDataset shapes: ((None, 300), (None,)), types: (tf.float32, tf.float32)>
# Epoch 1/50
# 584/584 [==============================] - 245s 414ms/step - loss: 2.4249 - mse: 0.8332 - mae: 0.6296 - mape: 113672.7656 - rmse: 0.9128 - correlation: 0.8814 - val_loss: 0.9028 - val_mse: 0.8650 - val_mae: 0.6262 - val_mape: 138045.1719 - val_rmse: 0.9300 - val_correlation: 0.9121
# Epoch 2/50
# 584/584 [==============================] - 159s 273ms/step - loss: 0.8393 - mse: 0.8227 - mae: 0.6256 - mape: 93894.8516 - rmse: 0.9071 - correlation: 0.8618 - val_loss: 0.8693 - val_mse: 0.8638 - val_mae: 0.6260 - val_mape: 185401.5156 - val_rmse: 0.9294 - val_correlation: 0.9086
# Epoch 3/50
# 584/584 [==============================] - 160s 274ms/step - loss: 0.8263 - mse: 0.8202 - mae: 0.6246 - mape: 97980.4375 - rmse: 0.9056 - correlation: 0.8516 - val_loss: 0.8674 - val_mse: 0.8633 - val_mae: 0.6247 - val_mape: 292970.0938 - val_rmse: 0.9292 - val_correlation: 0.9104
# Epoch 4/50
# 584/584 [==============================] - 159s 273ms/step - loss: 0.8238 - mse: 0.8182 - mae: 0.6238 - mape: 97802.2891 - rmse: 0.9045 - correlation: 0.8437 - val_loss: 0.8672 - val_mse: 0.8634 - val_mae: 0.6246 - val_mape: 341239.4688 - val_rmse: 0.9292 - val_correlation: 0.9090
# Epoch 5/50
# 584/584 [==============================] - 159s 273ms/step - loss: 0.8225 - mse: 0.8167 - mae: 0.6233 - mape: 100018.6719 - rmse: 0.9037 - correlation: 0.8374 - val_loss: 0.8674 - val_mse: 0.8639 - val_mae: 0.6245 - val_mape: 397262.5625 - val_rmse: 0.9294 - val_correlation: 0.9089
# Epoch 6/50
# 584/584 [==============================] - 159s 273ms/step - loss: 0.8213 - mse: 0.8152 - mae: 0.6227 - mape: 101788.1875 - rmse: 0.9029 - correlation: 0.8327 - val_loss: 0.8677 - val_mse: 0.8643 - val_mae: 0.6249 - val_mape: 419090.1562 - val_rmse: 0.9297 - val_correlation: 0.9085
# Epoch 7/50
# 584/584 [==============================] - 159s 273ms/step - loss: 0.8200 - mse: 0.8135 - mae: 0.6220 - mape: 101593.1094 - rmse: 0.9020 - correlation: 0.8274 - val_loss: 0.8675 - val_mse: 0.8643 - val_mae: 0.6246 - val_mape: 396851.3125 - val_rmse: 0.9297 - val_correlation: 0.9092
# Epoch 8/50
# 584/584 [==============================] - 160s 273ms/step - loss: 0.8180 - mse: 0.8112 - mae: 0.6210 - mape: 105189.4609 - rmse: 0.9006 - correlation: 0.8202 - val_loss: 0.8687 - val_mse: 0.8654 - val_mae: 0.6246 - val_mape: 373053.7188 - val_rmse: 0.9303 - val_correlation: 0.9125
# Epoch 9/50
# 584/584 [==============================] - 159s 273ms/step - loss: 0.8166 - mse: 0.8089 - mae: 0.6201 - mape: 106070.1641 - rmse: 0.8994 - correlation: 0.8138 - val_loss: 0.8690 - val_mse: 0.8652 - val_mae: 0.6247 - val_mape: 330169.9062 - val_rmse: 0.9302 - val_correlation: 0.9139
# Epoch 10/50
# 584/584 [==============================] - 159s 273ms/step - loss: 0.8144 - mse: 0.8062 - mae: 0.6190 - mape: 110744.0703 - rmse: 0.8979 - correlation: 0.8060 - val_loss: 0.8699 - val_mse: 0.8659 - val_mae: 0.6245 - val_mape: 361143.6875 - val_rmse: 0.9306 - val_correlation: 0.9139
# Epoch 11/50
# 584/584 [==============================] - 159s 273ms/step - loss: 0.8128 - mse: 0.8035 - mae: 0.6180 - mape: 111253.2891 - rmse: 0.8964 - correlation: 0.7984 - val_loss: 0.8714 - val_mse: 0.8668 - val_mae: 0.6248 - val_mape: 378730.0938 - val_rmse: 0.9310 - val_correlation: 0.9163
# Epoch 12/50
# 584/584 [==============================] - 160s 273ms/step - loss: 0.8103 - mse: 0.8007 - mae: 0.6170 - mape: 120047.0000 - rmse: 0.8948 - correlation: 0.7908 - val_loss: 0.8733 - val_mse: 0.8685 - val_mae: 0.6262 - val_mape: 363736.1562 - val_rmse: 0.9319 - val_correlation: 0.9202
# Epoch 13/50
# 584/584 [==============================] - 159s 273ms/step - loss: 0.8087 - mse: 0.7986 - mae: 0.6163 - mape: 116921.5938 - rmse: 0.8937 - correlation: 0.7851 - val_loss: 0.8736 - val_mse: 0.8684 - val_mae: 0.6262 - val_mape: 388582.0312 - val_rmse: 0.9319 - val_correlation: 0.9190
# Epoch 14/50
# 584/584 [==============================] - 159s 273ms/step - loss: 0.8060 - mse: 0.7957 - mae: 0.6153 - mape: 117847.1953 - rmse: 0.8920 - correlation: 0.7782 - val_loss: 0.8741 - val_mse: 0.8687 - val_mae: 0.6270 - val_mape: 370545.6875 - val_rmse: 0.9320 - val_correlation: 0.9223
# Pearson Score: 0.07891624945001356
# <PrefetchDataset shapes: ((None, 300), (None,)), types: (tf.float32, tf.float32)>
# Epoch 1/50
# 577/577 [==============================] - 241s 411ms/step - loss: 1.8979 - mse: 0.8447 - mae: 0.6349 - mape: 146347.7969 - rmse: 0.9191 - correlation: 0.8819 - val_loss: 0.8194 - val_mse: 0.8152 - val_mae: 0.6019 - val_mape: 58472.7578 - val_rmse: 0.9029 - val_correlation: 0.8927
# Epoch 2/50
# 577/577 [==============================] - 159s 275ms/step - loss: 0.8437 - mse: 0.8386 - mae: 0.6323 - mape: 145817.2344 - rmse: 0.9158 - correlation: 0.8652 - val_loss: 0.8143 - val_mse: 0.8103 - val_mae: 0.6007 - val_mape: 123501.5547 - val_rmse: 0.9001 - val_correlation: 0.8804
# Epoch 3/50
# 577/577 [==============================] - 159s 275ms/step - loss: 0.8410 - mse: 0.8359 - mae: 0.6313 - mape: 158990.2031 - rmse: 0.9143 - correlation: 0.8536 - val_loss: 0.8184 - val_mse: 0.8126 - val_mae: 0.6022 - val_mape: 151440.3594 - val_rmse: 0.9014 - val_correlation: 0.8767
# Epoch 4/50
# 577/577 [==============================] - 158s 274ms/step - loss: 0.8394 - mse: 0.8340 - mae: 0.6305 - mape: 163932.7031 - rmse: 0.9132 - correlation: 0.8466 - val_loss: 0.8216 - val_mse: 0.8155 - val_mae: 0.6040 - val_mape: 168594.8125 - val_rmse: 0.9031 - val_correlation: 0.8748
# Epoch 5/50
# 577/577 [==============================] - 158s 274ms/step - loss: 0.8382 - mse: 0.8320 - mae: 0.6296 - mape: 168698.8438 - rmse: 0.9121 - correlation: 0.8391 - val_loss: 0.8205 - val_mse: 0.8139 - val_mae: 0.6026 - val_mape: 167454.7500 - val_rmse: 0.9022 - val_correlation: 0.8715
# Epoch 6/50
# 577/577 [==============================] - 158s 274ms/step - loss: 0.8369 - mse: 0.8296 - mae: 0.6286 - mape: 176764.3438 - rmse: 0.9108 - correlation: 0.8314 - val_loss: 0.8205 - val_mse: 0.8136 - val_mae: 0.6015 - val_mape: 133200.3594 - val_rmse: 0.9020 - val_correlation: 0.8715
# Epoch 7/50
# 577/577 [==============================] - 158s 274ms/step - loss: 0.8354 - mse: 0.8272 - mae: 0.6276 - mape: 174257.8906 - rmse: 0.9095 - correlation: 0.8241 - val_loss: 0.8221 - val_mse: 0.8148 - val_mae: 0.6020 - val_mape: 136716.7656 - val_rmse: 0.9026 - val_correlation: 0.8709
# Epoch 8/50
# 577/577 [==============================] - 158s 274ms/step - loss: 0.8340 - mse: 0.8249 - mae: 0.6267 - mape: 177111.2188 - rmse: 0.9082 - correlation: 0.8166 - val_loss: 0.8255 - val_mse: 0.8174 - val_mae: 0.6031 - val_mape: 145478.5000 - val_rmse: 0.9041 - val_correlation: 0.8703
# Epoch 9/50
# 577/577 [==============================] - 158s 275ms/step - loss: 0.8316 - mse: 0.8221 - mae: 0.6255 - mape: 182730.2500 - rmse: 0.9067 - correlation: 0.8091 - val_loss: 0.8272 - val_mse: 0.8176 - val_mae: 0.6033 - val_mape: 128361.1484 - val_rmse: 0.9042 - val_correlation: 0.8705
# Epoch 10/50
# 577/577 [==============================] - 158s 274ms/step - loss: 0.8299 - mse: 0.8197 - mae: 0.6246 - mape: 186288.0469 - rmse: 0.9054 - correlation: 0.8025 - val_loss: 0.8250 - val_mse: 0.8148 - val_mae: 0.6024 - val_mape: 102333.8750 - val_rmse: 0.9027 - val_correlation: 0.8712
# Epoch 11/50
# 577/577 [==============================] - 158s 274ms/step - loss: 0.8279 - mse: 0.8170 - mae: 0.6236 - mape: 193054.3281 - rmse: 0.9039 - correlation: 0.7950 - val_loss: 0.8267 - val_mse: 0.8170 - val_mae: 0.6031 - val_mape: 109906.2578 - val_rmse: 0.9039 - val_correlation: 0.8756
# Epoch 12/50
# 577/577 [==============================] - 158s 274ms/step - loss: 0.8265 - mse: 0.8153 - mae: 0.6231 - mape: 202758.3750 - rmse: 0.9029 - correlation: 0.7904 - val_loss: 0.8319 - val_mse: 0.8204 - val_mae: 0.6050 - val_mape: 131121.5938 - val_rmse: 0.9057 - val_correlation: 0.8733
# Pearson Score: 0.12737949078330765
# CPU times: user 2h 40min 16s, sys: 9min 25s, total: 2h 49min 42s
# Wall time: 3h 43min 20s

# %% [markdown]
# ## Submission

# %%
# def preprocess_test(investment_id, feature):
#     return (investment_id, feature), 0

# def make_test_dataset(feature, investment_id, batch_size=1024):
#     ds = tf.data.Dataset.from_tensor_slices(((investment_id, feature)))
#     ds = ds.map(preprocess_test)
#     ds = ds.batch(batch_size).cache().prefetch(tf.data.AUTOTUNE)
#     return ds

def make_test_dataset(feature, batch_size=1024):
    ds = tf.data.Dataset.from_tensor_slices(((feature)))
    ds = ds.batch(batch_size).cache().prefetch(tf.data.AUTOTUNE)
    return ds

def inference(models, ds):
    y_preds = []
    for model in models:
        y_pred = model.predict(ds)
        y_preds.append(y_pred)
    return np.mean(y_preds, axis=0)

# %%
import ubiquant
env = ubiquant.make_env()
iter_test = env.iter_test() 
features = [f"f_{i}" for i in range(300)]
for (test_df, sample_prediction_df) in iter_test:
    ds = make_test_dataset(test_df[features])
    sample_prediction_df['target'] = inference(models, ds)
    env.predict(sample_prediction_df)
# Out:
# This version of the API is not optimized and should not be used to estimate the runtime of your code on the hidden test set.
